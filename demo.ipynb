# %%
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://annaelsaluiz:MongoDBdeployment1@cluster0.key8g5a.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#database
mydb= client['mydatabase']

#list all the database
client.list_database_names()

mycol=mydb['myfirstcollection']

myfirstrecord = {'fname':'Anna Elsa','lname':'Luiz','address':'Kochi'}
mycol.insert_one(myfirstrecord)

# %%
mysecrecord = {'fname':'Amanda','lname':'Luiz','address':'Kochi'}
mycol.insert_one(mysecrecord)

# %%
mythirdrecord = {'fname':'Amutha','lname':'Sunil','address':'TVM','Salary':50000}
mycol.insert_one(mythirdrecord)

# %%
multiplerecords=[
    {'ID':1,'fname':'Bayana','lname':'harris','address':'Kollam','Salary':50000},
    {'ID':2,'fname':'Amala','lname':'Sunil','address':'TVM','Salary':60000},
    {'ID':2,'fname':'devika','lname':'Jayaprakash','address':'ALP','Salary':45000},
    {'ID':3,'fname':'Sadhika ','lname':'antony','address':'PLK','Salary':22000},
    {'ID':4,'fname':'Zaigam','lname':'Fathima','address':'MLP','Salary':70000},
    {'ID':5,'fname':'Zajira','lname':'P A','address':'KZK','Salary':30000}

    ]

x= mycol.insert_many(multiplerecords)
print(x.inserted_ids)
# Out:
# [ObjectId('6512839489f1baa446db5c68'), ObjectId('6512839489f1baa446db5c69'), ObjectId('6512839489f1baa446db5c6a'), ObjectId('6512839489f1baa446db5c6b'), ObjectId('6512839489f1baa446db5c6c'), ObjectId('6512839489f1baa446db5c6d')]

# %%
print(mycol.find_one())
# Out:
# {'_id': ObjectId('6512839389f1baa446db5c65'), 'fname': 'Anna Elsa', 'lname': 'Luiz', 'address': 'Kochi'}

# %%
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('6512839389f1baa446db5c65'), 'fname': 'Anna Elsa', 'lname': 'Luiz', 'address': 'Kochi'}
# {'_id': ObjectId('6512839389f1baa446db5c66'), 'fname': 'Amanda', 'lname': 'Luiz', 'address': 'Kochi'}
# {'_id': ObjectId('6512839489f1baa446db5c67'), 'fname': 'Amutha', 'lname': 'Sunil', 'address': 'TVM', 'Salary': 50000}
# {'_id': ObjectId('6512839489f1baa446db5c68'), 'ID': 1, 'fname': 'Bayana', 'lname': 'harris', 'address': 'Kollam', 'Salary': 50000}
# {'_id': ObjectId('6512839489f1baa446db5c69'), 'ID': 2, 'fname': 'Amala', 'lname': 'Sunil', 'address': 'TVM', 'Salary': 60000}
# {'_id': ObjectId('6512839489f1baa446db5c6a'), 'ID': 2, 'fname': 'devika', 'lname': 'Jayaprakash', 'address': 'ALP', 'Salary': 45000}
# {'_id': ObjectId('6512839489f1baa446db5c6b'), 'ID': 3, 'fname': 'Sadhika ', 'lname': 'antony', 'address': 'PLK', 'Salary': 22000}
# {'_id': ObjectId('6512839489f1baa446db5c6c'), 'ID': 4, 'fname': 'Zaigam', 'lname': 'Fathima', 'address': 'MLP', 'Salary': 70000}
# {'_id': ObjectId('6512839489f1baa446db5c6d'), 'ID': 5, 'fname': 'Zajira', 'lname': 'P A', 'address': 'KZK', 'Salary': 30000}

# %%
mycol.find_one({"fname":"Anna Elsa"})
# Out:
# {'_id': ObjectId('6512839389f1baa446db5c65'),
#  'fname': 'Anna Elsa',
#  'lname': 'Luiz',
#  'address': 'Kochi'}

# %%
mycol.find_one({'fname':'Amanda'})
# Out:
# {'_id': ObjectId('6512839389f1baa446db5c66'),
#  'fname': 'Amanda',
#  'lname': 'Luiz',
#  'address': 'Kochi'}

# %%
for x in mycol.find().sort("fname",-1):
    print(x)
# Out:
# {'_id': ObjectId('6512839489f1baa446db5c6a'), 'ID': 2, 'fname': 'devika', 'lname': 'Jayaprakash', 'address': 'ALP', 'Salary': 45000}
# {'_id': ObjectId('6512839489f1baa446db5c6d'), 'ID': 5, 'fname': 'Zajira', 'lname': 'P A', 'address': 'KZK', 'Salary': 30000}
# {'_id': ObjectId('6512839489f1baa446db5c6c'), 'ID': 4, 'fname': 'Zaigam', 'lname': 'Fathima', 'address': 'MLP', 'Salary': 70000}
# {'_id': ObjectId('6512839489f1baa446db5c6b'), 'ID': 3, 'fname': 'Sadhika ', 'lname': 'antony', 'address': 'PLK', 'Salary': 22000}
# {'_id': ObjectId('6512839489f1baa446db5c68'), 'ID': 1, 'fname': 'Bayana', 'lname': 'harris', 'address': 'Kollam', 'Salary': 50000}
# {'_id': ObjectId('6512839389f1baa446db5c65'), 'fname': 'Anna Elsa', 'lname': 'Luiz', 'address': 'Kochi'}
# {'_id': ObjectId('6512839489f1baa446db5c67'), 'fname': 'Amutha', 'lname': 'Sunil', 'address': 'TVM', 'Salary': 50000}
# {'_id': ObjectId('6512839389f1baa446db5c66'), 'fname': 'Amanda', 'lname': 'Luiz', 'address': 'Kochi'}
# {'_id': ObjectId('6512839489f1baa446db5c69'), 'ID': 2, 'fname': 'Amala', 'lname': 'Sunil', 'address': 'TVM', 'Salary': 60000}

# %%
mycol.delete_one({'fname':'Bayana'})

# %%
mycol.delete_many({})

# %%
for x in mycol.find().limit(2):
    print(x)
# Out:
# {'_id': ObjectId('6512839389f1baa446db5c65'), 'fname': 'Anna Elsa', 'lname': 'Luiz', 'address': 'Kochi'}
# {'_id': ObjectId('6512839389f1baa446db5c66'), 'fname': 'Amanda', 'lname': 'Luiz', 'address': 'Kochi'}

# %%
myquery = {'fname':'Anna Elsa'}
newvale = {'$set':{'fname':'Anna'}}

# %%
mycol.update_one(myquery,newvale)

# %%
mycol.update_one({'lname':'Jayaprakash'},{'$set':{'lname':'Jaya Prakash'}})

# %%
for x in mycol.find({'Salary':{'$gt':50000}}):
    print(x)
# Out:
# {'_id': ObjectId('6512839489f1baa446db5c69'), 'ID': 2, 'fname': 'Amala', 'lname': 'Sunil', 'address': 'TVM', 'Salary': 60000}
# {'_id': ObjectId('6512839489f1baa446db5c6c'), 'ID': 4, 'fname': 'Zaigam', 'lname': 'Fathima', 'address': 'MLP', 'Salary': 70000}

# %%
mycol.delete_many({})

# %%
import pandas as pd

# %%
df=pd.read_csv('City.csv')

# %%
len(df.columns)
# Out:
# 7

# %%
mydb=client['mydatabase']

# %%
mycol2= mydb['City']

# %%
import json
json.loads(df.T.to_json())
# Out:
# {'0': {'ID': 6.0,
#   'NAME': 'Rotterdam',
#   'COUNTRYCODE': 'NLD',
#   'DISTRICT': 'Zuid-Holland',
#   'POPULATION': None,
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('6','Rotterdam','NLD','Zuid-Holland','');"},
#  '1': {'ID': 19.0,
#   'NAME': 'Zaanstad',
#   'COUNTRYCODE': 'NLD',
#   'DISTRICT': 'Noord-Holland',
#   'POPULATION': '135621',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('19','Zaanstad','NLD','Noord-Holland','135621');"},
#  '2': {'ID': 214.0,
#   'NAME': 'Porto Alegre',
#   'COUNTRYCODE': 'BRA',
#   'DISTRICT': 'Rio Grande do Sul',
#   'POPULATION': '1314032',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('214','Porto Alegre','BRA','Rio Grande do Sul','1314032');"},
#  '3': {'ID': 397.0,
#   'NAME': 'Lauro de Freitas',
#   'COUNTRYCODE': 'BRA',
#   'DISTRICT': 'Bahia',
#   'POPULATION': '109236',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('397','Lauro de Freitas','BRA','Bahia','109236');"},
#  '4': {'ID': 547.0,
#   'NAME': 'Dobric',
#   'COUNTRYCODE': 'BGR',
#   'DISTRICT': 'Varna',
#   'POPULATION': '100399',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('547','Dobric','BGR','Varna','100399');"},
#  '5': {'ID': 552.0,
#   'NAME': 'Bujumbura',
#   'COUNTRYCODE': 'BDI',
#   'DISTRICT': 'Bujumbura',
#   'POPULATION': '300000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('552','Bujumbura','BDI','Bujumbura','300000');"},
#  '6': {'ID': 554.0,
#   'NAME': 'Santiago de Chile',
#   'COUNTRYCODE': 'CHL',
#   'DISTRICT': 'Santiago',
#   'POPULATION': '4703954',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('554','Santiago de Chile','CHL','Santiago','4703954');"},
#  '7': {'ID': 626.0,
#   'NAME': 'al-Minya',
#   'COUNTRYCODE': 'EGY',
#   'DISTRICT': 'al-Minya',
#   'POPULATION': '201360',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('626','al-Minya','EGY','al-Minya','201360');"},
#  '8': {'ID': 646.0,
#   'NAME': 'Santa Ana',
#   'COUNTRYCODE': 'SLV',
#   'DISTRICT': 'Santa Ana',
#   'POPULATION': '139389',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('646','Santa Ana','SLV','Santa Ana','139389');"},
#  '9': {'ID': 762.0,
#   'NAME': 'Bahir',
#   'COUNTRYCODE': 'Dar',
#   'DISTRICT': 'ETH Amhara',
#   'POPULATION': '96140',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('762','Bahir','Dar','ETH Amhara','96140');"},
#  '10': {'ID': 796.0,
#   'NAME': 'Baguio',
#   'COUNTRYCODE': 'PHL',
#   'DISTRICT': 'CAR',
#   'POPULATION': '252386',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('796','Baguio','PHL','CAR','252386');"},
#  '11': {'ID': 896.0,
#   'NAME': 'Malungon',
#   'COUNTRYCODE': 'PHL',
#   'DISTRICT': 'Southern Mindanao',
#   'POPULATION': '93232',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('896','Malungon','PHL','Southern Mindanao','93232');"},
#  '12': {'ID': 904.0,
#   'NAME': 'Banjul',
#   'COUNTRYCODE': 'GMB',
#   'DISTRICT': 'Banjul',
#   'POPULATION': '42326',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('904','Banjul','GMB','Banjul','42326');"},
#  '13': {'ID': 924.0,
#   'NAME': 'Villa',
#   'COUNTRYCODE': 'Nueva',
#   'DISTRICT': 'GTM',
#   'POPULATION': '101295',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('924','Villa','Nueva','GTM','101295');"},
#  '14': {'ID': 990.0,
#   'NAME': 'Waru',
#   'COUNTRYCODE': 'IDN',
#   'DISTRICT': 'East Java',
#   'POPULATION': '124300',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('990','Waru','IDN','East Java','124300');"},
#  '15': {'ID': 1155.0,
#   'NAME': 'Latur',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Maharashtra',
#   'POPULATION': '197408',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1155','Latur','IND','Maharashtra','197408');"},
#  '16': {'ID': 1222.0,
#   'NAME': 'Tenali',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Andhra Pradesh',
#   'POPULATION': '143726',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1222','Tenali','IND','Andhra Pradesh','143726');"},
#  '17': {'ID': 1235.0,
#   'NAME': 'Tirunelveli',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Tamil Nadu',
#   'POPULATION': '135825',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1235','Tirunelveli','IND','Tamil Nadu','135825');"},
#  '18': {'ID': 1256.0,
#   'NAME': 'Alandur',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Tamil Nadu',
#   'POPULATION': '125244',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1256','Alandur','IND','Tamil Nadu','125244');"},
#  '19': {'ID': 1279.0,
#   'NAME': 'Neyveli',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Tamil Nadu',
#   'POPULATION': '118080',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1279','Neyveli','IND','Tamil Nadu','118080');"},
#  '20': {'ID': 1293.0,
#   'NAME': 'Pallavaram',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Tamil Nadu',
#   'POPULATION': '111866',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1293','Pallavaram','IND','Tamil Nadu','111866');"},
#  '21': {'ID': 1350.0,
#   'NAME': 'Dehri',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Bihar',
#   'POPULATION': '94526',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1350','Dehri','IND','Bihar','94526');"},
#  '22': {'ID': 1383.0,
#   'NAME': 'Tabriz',
#   'COUNTRYCODE': 'IRN',
#   'DISTRICT': 'East Azerbaidzan',
#   'POPULATION': '1191043',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1383','Tabriz','IRN','East Azerbaidzan','1191043');"},
#  '23': {'ID': 1385.0,
#   'NAME': 'Karaj',
#   'COUNTRYCODE': 'IRN',
#   'DISTRICT': 'Teheran',
#   'POPULATION': '940968',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1385','Karaj','IRN','Teheran','940968');"},
#  '24': {'ID': 1508.0,
#   'NAME': 'Bolzano',
#   'COUNTRYCODE': 'ITA',
#   'DISTRICT': 'Trentino-Alto Adige',
#   'POPULATION': '97232',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1508','Bolzano','ITA','Trentino-Alto Adige','97232');"},
#  '25': {'ID': 1520.0,
#   'NAME': 'Cesena',
#   'COUNTRYCODE': 'ITA',
#   'DISTRICT': 'Emilia-Romagna',
#   'POPULATION': '89852',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1520','Cesena','ITA','Emilia-Romagna','89852');"},
#  '26': {'ID': 1613.0,
#   'NAME': 'Neyagawa',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Osaka',
#   'POPULATION': '257315',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1613','Neyagawa','JPN','Osaka','257315');"},
#  '27': {'ID': 1630.0,
#   'NAME': 'Ageo',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Saitama',
#   'POPULATION': '209442',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1630','Ageo','JPN','Saitama','209442');"},
#  '28': {'ID': 1661.0,
#   'NAME': 'Sayama',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Saitama',
#   'POPULATION': '162472',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1661','Sayama','JPN','Saitama','162472');"},
#  '29': {'ID': 1681.0,
#   'NAME': 'Omuta',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Fukuoka',
#   'POPULATION': '142889',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1681','Omuta','JPN','Fukuoka','142889');"},
#  '30': {'ID': 1739.0,
#   'NAME': 'Tokuyama',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Yamaguchi',
#   'POPULATION': '107078',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1739','Tokuyama','JPN','Yamaguchi','107078');"},
#  '31': {'ID': 1793.0,
#   'NAME': 'Novi Sad',
#   'COUNTRYCODE': 'YUG',
#   'DISTRICT': 'Vojvodina',
#   'POPULATION': '179626',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1793','Novi Sad','YUG','Vojvodina','179626');"},
#  '32': {'ID': 1857.0,
#   'NAME': 'Kelowna',
#   'COUNTRYCODE': 'CAN',
#   'DISTRICT': 'British Colombia',
#   'POPULATION': '89442',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1857','Kelowna','CAN','British Colombia','89442');"},
#  '33': {'ID': 1895.0,
#   'NAME': 'Harbin',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Heilongjiang',
#   'POPULATION': '4289800',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1895','Harbin','CHN','Heilongjiang','4289800');"},
#  '34': {'ID': 1900.0,
#   'NAME': 'Changchun',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Jilin',
#   'POPULATION': '2812000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1900','Changchun','CHN','Jilin','2812000');"},
#  '35': {'ID': 1913.0,
#   'NAME': 'Lanzhou',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Gansu',
#   'POPULATION': '1565800',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1913','Lanzhou','CHN','Gansu','1565800');"},
#  '36': {'ID': 1947.0,
#   'NAME': 'Changzhou',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Jiangsu',
#   'POPULATION': '530000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1947','Changzhou','CHN','Jiangsu','530000');"},
#  '37': {'ID': 2070.0,
#   'NAME': 'Dezhou',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Shandong',
#   'POPULATION': '195485',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2070','Dezhou','CHN','Shandong','195485');"},
#  '38': {'ID': 2081.0,
#   'NAME': 'Heze',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Shandong',
#   'POPULATION': '189293',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2081','Heze','CHN','Shandong','189293');"},
#  '39': {'ID': 2111.0,
#   'NAME': 'Chenzhou',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Hunan',
#   'POPULATION': '169400',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2111','Chenzhou','CHN','Hunan','169400');"},
#  '40': {'ID': 2153.0,
#   'NAME': 'Xianning',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Hubei',
#   'POPULATION': '136811',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2153','Xianning','CHN','Hubei','136811');"},
#  '41': {'ID': 2192.0,
#   'NAME': 'Lhasa',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Tibet',
#   'POPULATION': '120000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2192','Lhasa','CHN','Tibet','120000');"},
#  '42': {'ID': 2193.0,
#   'NAME': 'Lianyuan',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Hunan',
#   'POPULATION': '118858',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2193','Lianyuan','CHN','Hunan','118858');"},
#  '43': {'ID': 2227.0,
#   'NAME': 'Xingcheng',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Liaoning',
#   'POPULATION': '102384',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2227','Xingcheng','CHN','Liaoning','102384');"},
#  '44': {'ID': 2273.0,
#   'NAME': 'Villavicencio',
#   'COUNTRYCODE': 'COL',
#   'DISTRICT': 'Meta',
#   'POPULATION': '273140',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2273','Villavicencio','COL','Meta','273140');"},
#  '45': {'ID': 2384.0,
#   'NAME': 'Tong-yong',
#   'COUNTRYCODE': 'KOR',
#   'DISTRICT': 'Kyongsangnam',
#   'POPULATION': '131717',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2384','Tong-yong','KOR','Kyongsangnam','131717');"},
#  '46': {'ID': 2386.0,
#   'NAME': 'Yongju',
#   'COUNTRYCODE': 'KOR',
#   'DISTRICT': 'Kyongsangbuk',
#   'POPULATION': '131097',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2386','Yongju','KOR','Kyongsangbuk','131097');"},
#  '47': {'ID': 2387.0,
#   'NAME': 'Chinhae',
#   'COUNTRYCODE': 'KOR',
#   'DISTRICT': 'Kyongsangnam',
#   'POPULATION': '125997',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2387','Chinhae','KOR','Kyongsangnam','125997');"},
#  '48': {'ID': 2388.0,
#   'NAME': 'Sangju',
#   'COUNTRYCODE': 'KOR',
#   'DISTRICT': 'Kyongsangbuk',
#   'POPULATION': '124116',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2388','Sangju','KOR','Kyongsangbuk','124116');"},
#  '49': {'ID': 2406.0,
#   'NAME': 'Herakleion',
#   'COUNTRYCODE': 'GRC',
#   'DISTRICT': 'Crete',
#   'POPULATION': '116178',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2406','Herakleion','GRC','Crete','116178');"},
#  '50': {'ID': 2440.0,
#   'NAME': 'Monrovia',
#   'COUNTRYCODE': 'LBR',
#   'DISTRICT': 'Montserrado',
#   'POPULATION': '850000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2440','Monrovia','LBR','Montserrado','850000');"},
#  '51': {'ID': 2462.0,
#   'NAME': 'Lilongwe',
#   'COUNTRYCODE': 'MWI',
#   'DISTRICT': 'Lilongwe',
#   'POPULATION': '435964',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2462','Lilongwe','MWI','Lilongwe','435964');"},
#  '52': {'ID': 2505.0,
#   'NAME': 'Taza',
#   'COUNTRYCODE': 'MAR',
#   'DISTRICT': 'Taza-Al Hoceima-Taou',
#   'POPULATION': '92700',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2505','Taza','MAR','Taza-Al Hoceima-Taou','92700');"},
#  '53': {'ID': 2555.0,
#   'NAME': 'Xalapa',
#   'COUNTRYCODE': 'MEX',
#   'DISTRICT': 'Veracruz',
#   'POPULATION': '390058',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2555','Xalapa','MEX','Veracruz','390058');"},
#  '54': {'ID': 2602.0,
#   'NAME': 'Ocosingo',
#   'COUNTRYCODE': 'MEX',
#   'DISTRICT': 'Chiapas',
#   'POPULATION': '171495',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2602','Ocosingo','MEX','Chiapas','171495');"},
#  '55': {'ID': 2609.0,
#   'NAME': 'Nogales',
#   'COUNTRYCODE': 'MEX',
#   'DISTRICT': 'Sonora',
#   'POPULATION': '159103',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2609','Nogales','MEX','Sonora','159103');"},
#  '56': {'ID': 2670.0,
#   'NAME': 'San Pedro Cholula',
#   'COUNTRYCODE': 'MEX',
#   'DISTRICT': 'Puebla',
#   'POPULATION': '99734',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2670','San Pedro Cholula','MEX','Puebla','99734');"},
#  '57': {'ID': 2689.0,
#   'NAME': 'Palikir',
#   'COUNTRYCODE': 'FSM',
#   'DISTRICT': 'Pohnpei',
#   'POPULATION': '8600',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2689','Palikir','FSM','Pohnpei','8600');"},
#  '58': {'ID': 2706.0,
#   'NAME': 'Tete',
#   'COUNTRYCODE': 'MOZ',
#   'DISTRICT': 'Tete',
#   'POPULATION': '101984',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2706','Tete','MOZ','Tete','101984');"},
#  '59': {'ID': 2716.0,
#   'NAME': 'Sittwe (Akyab)',
#   'COUNTRYCODE': 'MMR',
#   'DISTRICT': 'Rakhine',
#   'POPULATION': '137600',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2716','Sittwe (Akyab)','MMR','Rakhine','137600');"},
#  '60': {'ID': 2922.0,
#   'NAME': 'Carolina',
#   'COUNTRYCODE': 'PRI',
#   'DISTRICT': 'Carolina',
#   'POPULATION': '186076',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2922','Carolina','PRI','Carolina','186076');"},
#  '61': {'ID': 2967.0,
#   'NAME': 'Grudziadz',
#   'COUNTRYCODE': 'POL',
#   'DISTRICT': 'Kujawsko-Pomorskie',
#   'POPULATION': '102434',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2967','Grudziadz','POL','Kujawsko-Pomorskie','102434');"},
#  '62': {'ID': 2972.0,
#   'NAME': 'Malabo',
#   'COUNTRYCODE': 'GNQ',
#   'DISTRICT': 'Bioko',
#   'POPULATION': '40000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2972','Malabo','GNQ','Bioko','40000');"},
#  '63': {'ID': 3073.0,
#   'NAME': 'Essen',
#   'COUNTRYCODE': 'DEU',
#   'DISTRICT': 'Nordrhein-Westfalen',
#   'POPULATION': '599515',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3073','Essen','DEU','Nordrhein-Westfalen','599515');"},
#  '64': {'ID': 3169.0,
#   'NAME': 'Apia',
#   'COUNTRYCODE': 'WSM',
#   'DISTRICT': 'Upolu',
#   'POPULATION': '35900',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3169','Apia','WSM','Upolu','35900');"},
#  '65': {'ID': 3198.0,
#   'NAME': 'Dakar',
#   'COUNTRYCODE': 'SEN',
#   'DISTRICT': 'Cap-Vert',
#   'POPULATION': '785071',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3198','Dakar','SEN','Cap-Vert','785071');"},
#  '66': {'ID': 3253.0,
#   'NAME': 'Hama',
#   'COUNTRYCODE': 'SYR',
#   'DISTRICT': 'Hama',
#   'POPULATION': '343361',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3253','Hama','SYR','Hama','343361');"},
#  '67': {'ID': 3288.0,
#   'NAME': 'Luchou',
#   'COUNTRYCODE': 'TWN',
#   'DISTRICT': 'Taipei',
#   'POPULATION': '160516',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3288','Luchou','TWN','Taipei','160516');"},
#  '68': {'ID': 3309.0,
#   'NAME': 'Tanga',
#   'COUNTRYCODE': 'TZA',
#   'DISTRICT': 'Tanga',
#   'POPULATION': '137400',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3309','Tanga','TZA','Tanga','137400');"},
#  '69': {'ID': 3353.0,
#   'NAME': 'Sousse',
#   'COUNTRYCODE': 'TUN',
#   'DISTRICT': 'Sousse',
#   'POPULATION': '145900',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3353','Sousse','TUN','Sousse','145900');"},
#  '70': {'ID': 3377.0,
#   'NAME': 'Kahramanmaras',
#   'COUNTRYCODE': 'TUR',
#   'DISTRICT': 'Kahramanmaras',
#   'POPULATION': '245772',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3377','Kahramanmaras','TUR','Kahramanmaras','245772');"},
#  '71': {'ID': 3430.0,
#   'NAME': 'Odesa',
#   'COUNTRYCODE': 'UKR',
#   'DISTRICT': 'Odesa',
#   'POPULATION': '1011000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3430','Odesa','UKR','Odesa','1011000');"},
#  '72': {'ID': 3581.0,
#   'NAME': 'St Petersburg',
#   'COUNTRYCODE': 'RUS',
#   'DISTRICT': 'Pietari',
#   'POPULATION': '4694000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3581','St Petersburg','RUS','Pietari','4694000');"},
#  '73': {'ID': 3770.0,
#   'NAME': 'Hanoi',
#   'COUNTRYCODE': 'VNM',
#   'DISTRICT': 'Hanoi',
#   'POPULATION': '1410000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3770','Hanoi','VNM','Hanoi','1410000');"},
#  '74': {'ID': 3815.0,
#   'NAME': 'El Paso',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Texas',
#   'POPULATION': '563662',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3815','El Paso','USA','Texas','563662');"},
#  '75': {'ID': 3878.0,
#   'NAME': 'Scottsdale',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Arizona',
#   'POPULATION': '202705',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3878','Scottsdale','USA','Arizona','202705');"},
#  '76': {'ID': 3965.0,
#   'NAME': 'Corona',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'California',
#   'POPULATION': '124966',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3965','Corona','USA','California','124966');"},
#  '77': {'ID': 3973.0,
#   'NAME': 'Concord',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'California',
#   'POPULATION': '121780',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3973','Concord','USA','California','121780');"},
#  '78': {'ID': 3977.0,
#   'NAME': 'Cedar Rapids',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Iowa',
#   'POPULATION': '120758',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3977','Cedar Rapids','USA','Iowa','120758');"},
#  '79': {'ID': 3982.0,
#   'NAME': 'Coral Springs',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Florida',
#   'POPULATION': '117549',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3982','Coral Springs','USA','Florida','117549');"},
#  '80': {'ID': 4054.0,
#   'NAME': 'Fairfield',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'California',
#   'POPULATION': '92256',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('4054','Fairfield','USA','California','92256');"},
#  '81': {'ID': 4058.0,
#   'NAME': 'Boulder',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Colorado',
#   'POPULATION': '91238',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('4058','Boulder','USA','Colorado','91238');"},
#  '82': {'ID': 4061.0,
#   'NAME': 'Fall River',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Massachusetts',
#   'POPULATION': '90555',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('4061','Fall River','USA','Massachusetts','90555');"},
#  '83': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '84': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '85': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '86': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '87': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '88': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '89': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '90': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '91': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '92': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '93': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '94': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '95': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '96': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '97': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '98': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '99': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '100': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '101': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '102': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '103': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '104': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '105': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '106': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '107': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '108': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '109': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '110': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '111': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '112': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '113': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '114': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '115': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '116': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '117': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '118': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '119': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '120': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '121': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '122': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '123': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '124': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '125': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '126': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '127': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '128': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '129': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '130': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '131': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '132': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '133': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '134': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '135': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '136': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '137': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '138': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '139': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '140': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '141': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '142': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '143': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '144': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '145': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '146': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '147': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '148': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '149': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '150': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '151': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '152': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '153': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '154': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '155': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '156': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '157': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '158': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '159': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '160': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '161': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '162': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '163': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '164': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '165': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '166': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '167': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '168': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '169': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '170': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '171': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '172': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '173': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '174': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '175': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '176': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '177': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '178': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '179': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '180': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '181': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '182': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '183': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '184': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '185': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '186': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '187': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '188': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '189': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '190': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '191': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '192': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '193': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '194': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '195': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '196': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '197': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '198': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '199': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '200': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '201': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '202': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '203': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '204': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '205': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '206': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '207': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '208': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '209': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '210': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '211': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '212': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '213': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '214': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '215': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '216': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '217': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '218': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '219': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '220': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '221': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '222': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '223': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '224': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '225': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '226': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '227': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '228': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '229': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '230': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '231': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '232': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '233': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '234': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '235': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '236': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '237': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '238': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '239': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '240': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '241': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '242': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '243': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '244': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '245': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '246': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '247': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '248': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '249': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '250': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '251': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '252': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '253': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '254': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '255': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '256': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '257': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '258': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '259': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '260': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '261': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '262': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '263': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '264': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '265': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '266': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '267': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '268': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '269': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '270': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': 'City Table',
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '271': {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  '272': {'ID': None,
#   'NAME': 'ID',
#   'COUNTRYCODE': 'NAME',
#   'DISTRICT': 'COUNTRYCODE',
#   'POPULATION': 'DISTRICT',
#   'Unnamed: 5': 'POPULATION',
#   'Unnamed: 6': None},
#  '273': {'ID': None,
#   'NAME': '6',
#   'COUNTRYCODE': 'Rotterdam',
#   'DISTRICT': 'NLD',
#   'POPULATION': 'Zuid-Holland',
#   'Unnamed: 5': '593321',
#   'Unnamed: 6': None},
#  '274': {'ID': None,
#   'NAME': '19',
#   'COUNTRYCODE': 'Zaanstad',
#   'DISTRICT': 'NLD',
#   'POPULATION': 'Noord-Holland',
#   'Unnamed: 5': '135621',
#   'Unnamed: 6': None},
#  '275': {'ID': None,
#   'NAME': '214',
#   'COUNTRYCODE': 'Porto Alegre',
#   'DISTRICT': 'BRA',
#   'POPULATION': 'Rio Grande do Sul',
#   'Unnamed: 5': '1314032',
#   'Unnamed: 6': None},
#  '276': {'ID': None,
#   'NAME': '397',
#   'COUNTRYCODE': 'Lauro de Freitas',
#   'DISTRICT': 'BRA',
#   'POPULATION': 'Bahia',
#   'Unnamed: 5': '109236',
#   'Unnamed: 6': None},
#  '277': {'ID': None,
#   'NAME': '547',
#   'COUNTRYCODE': 'Dobric',
#   'DISTRICT': 'BGR',
#   'POPULATION': 'Varna',
#   'Unnamed: 5': '100399',
#   'Unnamed: 6': None},
#  '278': {'ID': None,
#   'NAME': '552',
#   'COUNTRYCODE': 'Bujumbura',
#   'DISTRICT': 'BDI',
#   'POPULATION': 'Bujumbura',
#   'Unnamed: 5': '300000',
#   'Unnamed: 6': None},
#  '279': {'ID': None,
#   'NAME': '554',
#   'COUNTRYCODE': 'Santiago de Chile',
#   'DISTRICT': 'CHL',
#   'POPULATION': 'Santiago',
#   'Unnamed: 5': '4703954',
#   'Unnamed: 6': None},
#  '280': {'ID': None,
#   'NAME': '626',
#   'COUNTRYCODE': 'al-Minya',
#   'DISTRICT': 'EGY',
#   'POPULATION': 'al-Minya',
#   'Unnamed: 5': '201360',
#   'Unnamed: 6': None},
#  '281': {'ID': None,
#   'NAME': '646',
#   'COUNTRYCODE': 'Santa Ana',
#   'DISTRICT': 'SLV',
#   'POPULATION': 'Santa Ana',
#   'Unnamed: 5': '139389',
#   'Unnamed: 6': None},
#  '282': {'ID': None,
#   'NAME': '762',
#   'COUNTRYCODE': 'Bahir',
#   'DISTRICT': 'Dar',
#   'POPULATION': 'ETH Amhara',
#   'Unnamed: 5': '96140',
#   'Unnamed: 6': None},
#  '283': {'ID': None,
#   'NAME': '796',
#   'COUNTRYCODE': 'Baguio',
#   'DISTRICT': 'PHL',
#   'POPULATION': 'CAR',
#   'Unnamed: 5': '252386',
#   'Unnamed: 6': None},
#  '284': {'ID': None,
#   'NAME': '896',
#   'COUNTRYCODE': 'Malungon',
#   'DISTRICT': 'PHL',
#   'POPULATION': 'Southern Mindanao',
#   'Unnamed: 5': '93232',
#   'Unnamed: 6': None},
#  '285': {'ID': None,
#   'NAME': '904',
#   'COUNTRYCODE': 'Banjul',
#   'DISTRICT': 'GMB',
#   'POPULATION': 'Banjul',
#   'Unnamed: 5': '42326',
#   'Unnamed: 6': None},
#  '286': {'ID': None,
#   'NAME': '924',
#   'COUNTRYCODE': 'Villa',
#   'DISTRICT': 'Nueva',
#   'POPULATION': 'GTM',
#   'Unnamed: 5': '101295',
#   'Unnamed: 6': None},
#  '287': {'ID': None,
#   'NAME': '990',
#   'COUNTRYCODE': 'Waru',
#   'DISTRICT': 'IDN',
#   'POPULATION': 'East Java',
#   'Unnamed: 5': '124300',
#   'Unnamed: 6': None},
#  '288': {'ID': None,
#   'NAME': '1155',
#   'COUNTRYCODE': 'Latur',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Maharashtra',
#   'Unnamed: 5': '197408',
#   'Unnamed: 6': None},
#  '289': {'ID': None,
#   'NAME': '1222',
#   'COUNTRYCODE': 'Tenali',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Andhra Pradesh',
#   'Unnamed: 5': '143726',
#   'Unnamed: 6': None},
#  '290': {'ID': None,
#   'NAME': '1235',
#   'COUNTRYCODE': 'Tirunelveli',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Tamil Nadu',
#   'Unnamed: 5': '135825',
#   'Unnamed: 6': None},
#  '291': {'ID': None,
#   'NAME': '1256',
#   'COUNTRYCODE': 'Alandur',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Tamil Nadu',
#   'Unnamed: 5': '125244',
#   'Unnamed: 6': None},
#  '292': {'ID': None,
#   'NAME': '1279',
#   'COUNTRYCODE': 'Neyveli',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Tamil Nadu',
#   'Unnamed: 5': '118080',
#   'Unnamed: 6': None},
#  '293': {'ID': None,
#   'NAME': '1293',
#   'COUNTRYCODE': 'Pallavaram',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Tamil Nadu',
#   'Unnamed: 5': '111866',
#   'Unnamed: 6': None},
#  '294': {'ID': None,
#   'NAME': '1350',
#   'COUNTRYCODE': 'Dehri',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Bihar',
#   'Unnamed: 5': '94526',
#   'Unnamed: 6': None},
#  '295': {'ID': None,
#   'NAME': '1383',
#   'COUNTRYCODE': 'Tabriz',
#   'DISTRICT': 'IRN',
#   'POPULATION': 'East Azerbaidzan',
#   'Unnamed: 5': '1191043',
#   'Unnamed: 6': None},
#  '296': {'ID': None,
#   'NAME': '1385',
#   'COUNTRYCODE': 'Karaj',
#   'DISTRICT': 'IRN',
#   'POPULATION': 'Teheran',
#   'Unnamed: 5': '940968',
#   'Unnamed: 6': None},
#  '297': {'ID': None,
#   'NAME': '1508',
#   'COUNTRYCODE': 'Bolzano',
#   'DISTRICT': 'ITA',
#   'POPULATION': 'Trentino-Alto Adige',
#   'Unnamed: 5': '97232',
#   'Unnamed: 6': None},
#  '298': {'ID': None,
#   'NAME': '1520',
#   'COUNTRYCODE': 'Cesena',
#   'DISTRICT': 'ITA',
#   'POPULATION': 'Emilia-Romagna',
#   'Unnamed: 5': '89852',
#   'Unnamed: 6': None},
#  '299': {'ID': None,
#   'NAME': '1613',
#   'COUNTRYCODE': 'Neyagawa',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Osaka',
#   'Unnamed: 5': '257315',
#   'Unnamed: 6': None},
#  '300': {'ID': None,
#   'NAME': '1630',
#   'COUNTRYCODE': 'Ageo',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Saitama',
#   'Unnamed: 5': '209442',
#   'Unnamed: 6': None},
#  '301': {'ID': None,
#   'NAME': '1661',
#   'COUNTRYCODE': 'Sayama',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Saitama',
#   'Unnamed: 5': '162472',
#   'Unnamed: 6': None},
#  '302': {'ID': None,
#   'NAME': '1681',
#   'COUNTRYCODE': 'Omuta',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Fukuoka',
#   'Unnamed: 5': '142889',
#   'Unnamed: 6': None},
#  '303': {'ID': None,
#   'NAME': '1739',
#   'COUNTRYCODE': 'Tokuyama',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Yamaguchi',
#   'Unnamed: 5': '107078',
#   'Unnamed: 6': None},
#  '304': {'ID': None,
#   'NAME': '1793',
#   'COUNTRYCODE': 'Novi Sad',
#   'DISTRICT': 'YUG',
#   'POPULATION': 'Vojvodina',
#   'Unnamed: 5': '179626',
#   'Unnamed: 6': None},
#  '305': {'ID': None,
#   'NAME': '1857',
#   'COUNTRYCODE': 'Kelowna',
#   'DISTRICT': 'CAN',
#   'POPULATION': 'British Colombia',
#   'Unnamed: 5': '89442',
#   'Unnamed: 6': None},
#  '306': {'ID': None,
#   'NAME': '1895',
#   'COUNTRYCODE': 'Harbin',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Heilongjiang',
#   'Unnamed: 5': '4289800',
#   'Unnamed: 6': None},
#  '307': {'ID': None,
#   'NAME': '1900',
#   'COUNTRYCODE': 'Changchun',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Jilin',
#   'Unnamed: 5': '2812000',
#   'Unnamed: 6': None},
#  '308': {'ID': None,
#   'NAME': '1913',
#   'COUNTRYCODE': 'Lanzhou',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Gansu',
#   'Unnamed: 5': '1565800',
#   'Unnamed: 6': None},
#  '309': {'ID': None,
#   'NAME': '1947',
#   'COUNTRYCODE': 'Changzhou',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Jiangsu',
#   'Unnamed: 5': '530000',
#   'Unnamed: 6': None},
#  '310': {'ID': None,
#   'NAME': '2070',
#   'COUNTRYCODE': 'Dezhou',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Shandong',
#   'Unnamed: 5': '195485',
#   'Unnamed: 6': None},
#  '311': {'ID': None,
#   'NAME': '2081',
#   'COUNTRYCODE': 'Heze',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Shandong',
#   'Unnamed: 5': '189293',
#   'Unnamed: 6': None},
#  '312': {'ID': None,
#   'NAME': '2111',
#   'COUNTRYCODE': 'Chenzhou',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Hunan',
#   'Unnamed: 5': '169400',
#   'Unnamed: 6': None},
#  '313': {'ID': None,
#   'NAME': '2153',
#   'COUNTRYCODE': 'Xianning',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Hubei',
#   'Unnamed: 5': '136811',
#   'Unnamed: 6': None},
#  '314': {'ID': None,
#   'NAME': '2192',
#   'COUNTRYCODE': 'Lhasa',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Tibet',
#   'Unnamed: 5': '120000',
#   'Unnamed: 6': None},
#  '315': {'ID': None,
#   'NAME': '2193',
#   'COUNTRYCODE': 'Lianyuan',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Hunan',
#   'Unnamed: 5': '118858',
#   'Unnamed: 6': None},
#  '316': {'ID': None,
#   'NAME': '2227',
#   'COUNTRYCODE': 'Xingcheng',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Liaoning',
#   'Unnamed: 5': '102384',
#   'Unnamed: 6': None},
#  '317': {'ID': None,
#   'NAME': '2273',
#   'COUNTRYCODE': 'Villavicencio',
#   'DISTRICT': 'COL',
#   'POPULATION': 'Meta',
#   'Unnamed: 5': '273140',
#   'Unnamed: 6': None},
#  '318': {'ID': None,
#   'NAME': '2384',
#   'COUNTRYCODE': 'Tong-yong',
#   'DISTRICT': 'KOR',
#   'POPULATION': 'Kyongsangnam',
#   'Unnamed: 5': '131717',
#   'Unnamed: 6': None},
#  '319': {'ID': None,
#   'NAME': '2386',
#   'COUNTRYCODE': 'Yongju',
#   'DISTRICT': 'KOR',
#   'POPULATION': 'Kyongsangbuk',
#   'Unnamed: 5': '131097',
#   'Unnamed: 6': None},
#  '320': {'ID': None,
#   'NAME': '2387',
#   'COUNTRYCODE': 'Chinhae',
#   'DISTRICT': 'KOR',
#   'POPULATION': 'Kyongsangnam',
#   'Unnamed: 5': '125997',
#   'Unnamed: 6': None},
#  '321': {'ID': None,
#   'NAME': '2388',
#   'COUNTRYCODE': 'Sangju',
#   'DISTRICT': 'KOR',
#   'POPULATION': 'Kyongsangbuk',
#   'Unnamed: 5': '124116',
#   'Unnamed: 6': None},
#  '322': {'ID': None,
#   'NAME': '2406',
#   'COUNTRYCODE': 'Herakleion',
#   'DISTRICT': 'GRC',
#   'POPULATION': 'Crete',
#   'Unnamed: 5': '116178',
#   'Unnamed: 6': None},
#  '323': {'ID': None,
#   'NAME': '2440',
#   'COUNTRYCODE': 'Monrovia',
#   'DISTRICT': 'LBR',
#   'POPULATION': 'Montserrado',
#   'Unnamed: 5': '850000',
#   'Unnamed: 6': None},
#  '324': {'ID': None,
#   'NAME': '2462',
#   'COUNTRYCODE': 'Lilongwe',
#   'DISTRICT': 'MWI',
#   'POPULATION': 'Lilongwe',
#   'Unnamed: 5': '435964',
#   'Unnamed: 6': None},
#  '325': {'ID': None,
#   'NAME': '2505',
#   'COUNTRYCODE': 'Taza',
#   'DISTRICT': 'MAR',
#   'POPULATION': 'Taza-Al Hoceima-Taou',
#   'Unnamed: 5': '92700',
#   'Unnamed: 6': None},
#  '326': {'ID': None,
#   'NAME': '2555',
#   'COUNTRYCODE': 'Xalapa',
#   'DISTRICT': 'MEX',
#   'POPULATION': 'Veracruz',
#   'Unnamed: 5': '390058',
#   'Unnamed: 6': None},
#  '327': {'ID': None,
#   'NAME': '2602',
#   'COUNTRYCODE': 'Ocosingo',
#   'DISTRICT': 'MEX',
#   'POPULATION': 'Chiapas',
#   'Unnamed: 5': '171495',
#   'Unnamed: 6': None},
#  '328': {'ID': None,
#   'NAME': '2609',
#   'COUNTRYCODE': 'Nogales',
#   'DISTRICT': 'MEX',
#   'POPULATION': 'Sonora',
#   'Unnamed: 5': '159103',
#   'Unnamed: 6': None},
#  '329': {'ID': None,
#   'NAME': '2670',
#   'COUNTRYCODE': 'San Pedro Cholula',
#   'DISTRICT': 'MEX',
#   'POPULATION': 'Puebla',
#   'Unnamed: 5': '99734',
#   'Unnamed: 6': None},
#  '330': {'ID': None,
#   'NAME': '2689',
#   'COUNTRYCODE': 'Palikir',
#   'DISTRICT': 'FSM',
#   'POPULATION': 'Pohnpei',
#   'Unnamed: 5': '8600',
#   'Unnamed: 6': None},
#  '331': {'ID': None,
#   'NAME': '2706',
#   'COUNTRYCODE': 'Tete',
#   'DISTRICT': 'MOZ',
#   'POPULATION': 'Tete',
#   'Unnamed: 5': '101984',
#   'Unnamed: 6': None},
#  '332': {'ID': None,
#   'NAME': '2716',
#   'COUNTRYCODE': 'Sittwe (Akyab)',
#   'DISTRICT': 'MMR',
#   'POPULATION': 'Rakhine',
#   'Unnamed: 5': '137600',
#   'Unnamed: 6': None},
#  '333': {'ID': None,
#   'NAME': '2922',
#   'COUNTRYCODE': 'Carolina',
#   'DISTRICT': 'PRI',
#   'POPULATION': 'Carolina',
#   'Unnamed: 5': '186076',
#   'Unnamed: 6': None},
#  '334': {'ID': None,
#   'NAME': '2967',
#   'COUNTRYCODE': 'Grudziadz',
#   'DISTRICT': 'POL',
#   'POPULATION': 'Kujawsko-Pomorskie',
#   'Unnamed: 5': '102434',
#   'Unnamed: 6': None},
#  '335': {'ID': None,
#   'NAME': '2972',
#   'COUNTRYCODE': 'Malabo',
#   'DISTRICT': 'GNQ',
#   'POPULATION': 'Bioko',
#   'Unnamed: 5': '40000',
#   'Unnamed: 6': None},
#  '336': {'ID': None,
#   'NAME': '3073',
#   'COUNTRYCODE': 'Essen',
#   'DISTRICT': 'DEU',
#   'POPULATION': 'Nordrhein-Westfalen',
#   'Unnamed: 5': '599515',
#   'Unnamed: 6': None},
#  '337': {'ID': None,
#   'NAME': '3169',
#   'COUNTRYCODE': 'Apia',
#   'DISTRICT': 'WSM',
#   'POPULATION': 'Upolu',
#   'Unnamed: 5': '35900',
#   'Unnamed: 6': None},
#  '338': {'ID': None,
#   'NAME': '3198',
#   'COUNTRYCODE': 'Dakar',
#   'DISTRICT': 'SEN',
#   'POPULATION': 'Cap-Vert',
#   'Unnamed: 5': '785071',
#   'Unnamed: 6': None},
#  '339': {'ID': None,
#   'NAME': '3253',
#   'COUNTRYCODE': 'Hama',
#   'DISTRICT': 'SYR',
#   'POPULATION': 'Hama',
#   'Unnamed: 5': '343361',
#   'Unnamed: 6': None},
#  '340': {'ID': None,
#   'NAME': '3288',
#   'COUNTRYCODE': 'Luchou',
#   'DISTRICT': 'TWN',
#   'POPULATION': 'Taipei',
#   'Unnamed: 5': '160516',
#   'Unnamed: 6': None},
#  '341': {'ID': None,
#   'NAME': '3309',
#   'COUNTRYCODE': 'Tanga',
#   'DISTRICT': 'TZA',
#   'POPULATION': 'Tanga',
#   'Unnamed: 5': '137400',
#   'Unnamed: 6': None},
#  '342': {'ID': None,
#   'NAME': '3353',
#   'COUNTRYCODE': 'Sousse',
#   'DISTRICT': 'TUN',
#   'POPULATION': 'Sousse',
#   'Unnamed: 5': '145900',
#   'Unnamed: 6': None},
#  '343': {'ID': None,
#   'NAME': '3377',
#   'COUNTRYCODE': 'Kahramanmaras',
#   'DISTRICT': 'TUR',
#   'POPULATION': 'Kahramanmaras',
#   'Unnamed: 5': '245772',
#   'Unnamed: 6': None},
#  '344': {'ID': None,
#   'NAME': '3430',
#   'COUNTRYCODE': 'Odesa',
#   'DISTRICT': 'UKR',
#   'POPULATION': 'Odesa',
#   'Unnamed: 5': '1011000',
#   'Unnamed: 6': None},
#  '345': {'ID': None,
#   'NAME': '3581',
#   'COUNTRYCODE': 'St Petersburg',
#   'DISTRICT': 'RUS',
#   'POPULATION': 'Pietari',
#   'Unnamed: 5': '4694000',
#   'Unnamed: 6': None},
#  '346': {'ID': None,
#   'NAME': '3770',
#   'COUNTRYCODE': 'Hanoi',
#   'DISTRICT': 'VNM',
#   'POPULATION': 'Hanoi',
#   'Unnamed: 5': '1410000',
#   'Unnamed: 6': None},
#  '347': {'ID': None,
#   'NAME': '3815',
#   'COUNTRYCODE': 'El Paso',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Texas',
#   'Unnamed: 5': '563662',
#   'Unnamed: 6': None},
#  '348': {'ID': None,
#   'NAME': '3878',
#   'COUNTRYCODE': 'Scottsdale',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Arizona',
#   'Unnamed: 5': '202705',
#   'Unnamed: 6': None},
#  '349': {'ID': None,
#   'NAME': '3965',
#   'COUNTRYCODE': 'Corona',
#   'DISTRICT': 'USA',
#   'POPULATION': 'California',
#   'Unnamed: 5': '124966',
#   'Unnamed: 6': None},
#  '350': {'ID': None,
#   'NAME': '3973',
#   'COUNTRYCODE': 'Concord',
#   'DISTRICT': 'USA',
#   'POPULATION': 'California',
#   'Unnamed: 5': '121780',
#   'Unnamed: 6': None},
#  '351': {'ID': None,
#   'NAME': '3977',
#   'COUNTRYCODE': 'Cedar Rapids',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Iowa',
#   'Unnamed: 5': '120758',
#   'Unnamed: 6': None},
#  '352': {'ID': None,
#   'NAME': '3982',
#   'COUNTRYCODE': 'Coral Springs',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Florida',
#   'Unnamed: 5': '117549',
#   'Unnamed: 6': None},
#  '353': {'ID': None,
#   'NAME': '4054',
#   'COUNTRYCODE': 'Fairfield',
#   'DISTRICT': 'USA',
#   'POPULATION': 'California',
#   'Unnamed: 5': '92256',
#   'Unnamed: 6': None},
#  '354': {'ID': None,
#   'NAME': '4058',
#   'COUNTRYCODE': 'Boulder',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Colorado',
#   'Unnamed: 5': '91238',
#   'Unnamed: 6': None},
#  '355': {'ID': None,
#   'NAME': '4061',
#   'COUNTRYCODE': 'Fall River',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Massachusetts',
#   'Unnamed: 5': '90555',
#   'Unnamed: 6': None}}

# %%
list(json.loads(df.T.to_json()).values())
# Out:
# [{'ID': 6.0,
#   'NAME': 'Rotterdam',
#   'COUNTRYCODE': 'NLD',
#   'DISTRICT': 'Zuid-Holland',
#   'POPULATION': None,
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('6','Rotterdam','NLD','Zuid-Holland','');"},
#  {'ID': 19.0,
#   'NAME': 'Zaanstad',
#   'COUNTRYCODE': 'NLD',
#   'DISTRICT': 'Noord-Holland',
#   'POPULATION': '135621',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('19','Zaanstad','NLD','Noord-Holland','135621');"},
#  {'ID': 214.0,
#   'NAME': 'Porto Alegre',
#   'COUNTRYCODE': 'BRA',
#   'DISTRICT': 'Rio Grande do Sul',
#   'POPULATION': '1314032',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('214','Porto Alegre','BRA','Rio Grande do Sul','1314032');"},
#  {'ID': 397.0,
#   'NAME': 'Lauro de Freitas',
#   'COUNTRYCODE': 'BRA',
#   'DISTRICT': 'Bahia',
#   'POPULATION': '109236',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('397','Lauro de Freitas','BRA','Bahia','109236');"},
#  {'ID': 547.0,
#   'NAME': 'Dobric',
#   'COUNTRYCODE': 'BGR',
#   'DISTRICT': 'Varna',
#   'POPULATION': '100399',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('547','Dobric','BGR','Varna','100399');"},
#  {'ID': 552.0,
#   'NAME': 'Bujumbura',
#   'COUNTRYCODE': 'BDI',
#   'DISTRICT': 'Bujumbura',
#   'POPULATION': '300000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('552','Bujumbura','BDI','Bujumbura','300000');"},
#  {'ID': 554.0,
#   'NAME': 'Santiago de Chile',
#   'COUNTRYCODE': 'CHL',
#   'DISTRICT': 'Santiago',
#   'POPULATION': '4703954',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('554','Santiago de Chile','CHL','Santiago','4703954');"},
#  {'ID': 626.0,
#   'NAME': 'al-Minya',
#   'COUNTRYCODE': 'EGY',
#   'DISTRICT': 'al-Minya',
#   'POPULATION': '201360',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('626','al-Minya','EGY','al-Minya','201360');"},
#  {'ID': 646.0,
#   'NAME': 'Santa Ana',
#   'COUNTRYCODE': 'SLV',
#   'DISTRICT': 'Santa Ana',
#   'POPULATION': '139389',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('646','Santa Ana','SLV','Santa Ana','139389');"},
#  {'ID': 762.0,
#   'NAME': 'Bahir',
#   'COUNTRYCODE': 'Dar',
#   'DISTRICT': 'ETH Amhara',
#   'POPULATION': '96140',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('762','Bahir','Dar','ETH Amhara','96140');"},
#  {'ID': 796.0,
#   'NAME': 'Baguio',
#   'COUNTRYCODE': 'PHL',
#   'DISTRICT': 'CAR',
#   'POPULATION': '252386',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('796','Baguio','PHL','CAR','252386');"},
#  {'ID': 896.0,
#   'NAME': 'Malungon',
#   'COUNTRYCODE': 'PHL',
#   'DISTRICT': 'Southern Mindanao',
#   'POPULATION': '93232',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('896','Malungon','PHL','Southern Mindanao','93232');"},
#  {'ID': 904.0,
#   'NAME': 'Banjul',
#   'COUNTRYCODE': 'GMB',
#   'DISTRICT': 'Banjul',
#   'POPULATION': '42326',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('904','Banjul','GMB','Banjul','42326');"},
#  {'ID': 924.0,
#   'NAME': 'Villa',
#   'COUNTRYCODE': 'Nueva',
#   'DISTRICT': 'GTM',
#   'POPULATION': '101295',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('924','Villa','Nueva','GTM','101295');"},
#  {'ID': 990.0,
#   'NAME': 'Waru',
#   'COUNTRYCODE': 'IDN',
#   'DISTRICT': 'East Java',
#   'POPULATION': '124300',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('990','Waru','IDN','East Java','124300');"},
#  {'ID': 1155.0,
#   'NAME': 'Latur',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Maharashtra',
#   'POPULATION': '197408',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1155','Latur','IND','Maharashtra','197408');"},
#  {'ID': 1222.0,
#   'NAME': 'Tenali',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Andhra Pradesh',
#   'POPULATION': '143726',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1222','Tenali','IND','Andhra Pradesh','143726');"},
#  {'ID': 1235.0,
#   'NAME': 'Tirunelveli',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Tamil Nadu',
#   'POPULATION': '135825',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1235','Tirunelveli','IND','Tamil Nadu','135825');"},
#  {'ID': 1256.0,
#   'NAME': 'Alandur',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Tamil Nadu',
#   'POPULATION': '125244',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1256','Alandur','IND','Tamil Nadu','125244');"},
#  {'ID': 1279.0,
#   'NAME': 'Neyveli',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Tamil Nadu',
#   'POPULATION': '118080',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1279','Neyveli','IND','Tamil Nadu','118080');"},
#  {'ID': 1293.0,
#   'NAME': 'Pallavaram',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Tamil Nadu',
#   'POPULATION': '111866',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1293','Pallavaram','IND','Tamil Nadu','111866');"},
#  {'ID': 1350.0,
#   'NAME': 'Dehri',
#   'COUNTRYCODE': 'IND',
#   'DISTRICT': 'Bihar',
#   'POPULATION': '94526',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1350','Dehri','IND','Bihar','94526');"},
#  {'ID': 1383.0,
#   'NAME': 'Tabriz',
#   'COUNTRYCODE': 'IRN',
#   'DISTRICT': 'East Azerbaidzan',
#   'POPULATION': '1191043',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1383','Tabriz','IRN','East Azerbaidzan','1191043');"},
#  {'ID': 1385.0,
#   'NAME': 'Karaj',
#   'COUNTRYCODE': 'IRN',
#   'DISTRICT': 'Teheran',
#   'POPULATION': '940968',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1385','Karaj','IRN','Teheran','940968');"},
#  {'ID': 1508.0,
#   'NAME': 'Bolzano',
#   'COUNTRYCODE': 'ITA',
#   'DISTRICT': 'Trentino-Alto Adige',
#   'POPULATION': '97232',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1508','Bolzano','ITA','Trentino-Alto Adige','97232');"},
#  {'ID': 1520.0,
#   'NAME': 'Cesena',
#   'COUNTRYCODE': 'ITA',
#   'DISTRICT': 'Emilia-Romagna',
#   'POPULATION': '89852',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1520','Cesena','ITA','Emilia-Romagna','89852');"},
#  {'ID': 1613.0,
#   'NAME': 'Neyagawa',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Osaka',
#   'POPULATION': '257315',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1613','Neyagawa','JPN','Osaka','257315');"},
#  {'ID': 1630.0,
#   'NAME': 'Ageo',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Saitama',
#   'POPULATION': '209442',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1630','Ageo','JPN','Saitama','209442');"},
#  {'ID': 1661.0,
#   'NAME': 'Sayama',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Saitama',
#   'POPULATION': '162472',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1661','Sayama','JPN','Saitama','162472');"},
#  {'ID': 1681.0,
#   'NAME': 'Omuta',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Fukuoka',
#   'POPULATION': '142889',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1681','Omuta','JPN','Fukuoka','142889');"},
#  {'ID': 1739.0,
#   'NAME': 'Tokuyama',
#   'COUNTRYCODE': 'JPN',
#   'DISTRICT': 'Yamaguchi',
#   'POPULATION': '107078',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1739','Tokuyama','JPN','Yamaguchi','107078');"},
#  {'ID': 1793.0,
#   'NAME': 'Novi Sad',
#   'COUNTRYCODE': 'YUG',
#   'DISTRICT': 'Vojvodina',
#   'POPULATION': '179626',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1793','Novi Sad','YUG','Vojvodina','179626');"},
#  {'ID': 1857.0,
#   'NAME': 'Kelowna',
#   'COUNTRYCODE': 'CAN',
#   'DISTRICT': 'British Colombia',
#   'POPULATION': '89442',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1857','Kelowna','CAN','British Colombia','89442');"},
#  {'ID': 1895.0,
#   'NAME': 'Harbin',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Heilongjiang',
#   'POPULATION': '4289800',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1895','Harbin','CHN','Heilongjiang','4289800');"},
#  {'ID': 1900.0,
#   'NAME': 'Changchun',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Jilin',
#   'POPULATION': '2812000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1900','Changchun','CHN','Jilin','2812000');"},
#  {'ID': 1913.0,
#   'NAME': 'Lanzhou',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Gansu',
#   'POPULATION': '1565800',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1913','Lanzhou','CHN','Gansu','1565800');"},
#  {'ID': 1947.0,
#   'NAME': 'Changzhou',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Jiangsu',
#   'POPULATION': '530000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('1947','Changzhou','CHN','Jiangsu','530000');"},
#  {'ID': 2070.0,
#   'NAME': 'Dezhou',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Shandong',
#   'POPULATION': '195485',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2070','Dezhou','CHN','Shandong','195485');"},
#  {'ID': 2081.0,
#   'NAME': 'Heze',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Shandong',
#   'POPULATION': '189293',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2081','Heze','CHN','Shandong','189293');"},
#  {'ID': 2111.0,
#   'NAME': 'Chenzhou',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Hunan',
#   'POPULATION': '169400',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2111','Chenzhou','CHN','Hunan','169400');"},
#  {'ID': 2153.0,
#   'NAME': 'Xianning',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Hubei',
#   'POPULATION': '136811',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2153','Xianning','CHN','Hubei','136811');"},
#  {'ID': 2192.0,
#   'NAME': 'Lhasa',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Tibet',
#   'POPULATION': '120000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2192','Lhasa','CHN','Tibet','120000');"},
#  {'ID': 2193.0,
#   'NAME': 'Lianyuan',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Hunan',
#   'POPULATION': '118858',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2193','Lianyuan','CHN','Hunan','118858');"},
#  {'ID': 2227.0,
#   'NAME': 'Xingcheng',
#   'COUNTRYCODE': 'CHN',
#   'DISTRICT': 'Liaoning',
#   'POPULATION': '102384',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2227','Xingcheng','CHN','Liaoning','102384');"},
#  {'ID': 2273.0,
#   'NAME': 'Villavicencio',
#   'COUNTRYCODE': 'COL',
#   'DISTRICT': 'Meta',
#   'POPULATION': '273140',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2273','Villavicencio','COL','Meta','273140');"},
#  {'ID': 2384.0,
#   'NAME': 'Tong-yong',
#   'COUNTRYCODE': 'KOR',
#   'DISTRICT': 'Kyongsangnam',
#   'POPULATION': '131717',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2384','Tong-yong','KOR','Kyongsangnam','131717');"},
#  {'ID': 2386.0,
#   'NAME': 'Yongju',
#   'COUNTRYCODE': 'KOR',
#   'DISTRICT': 'Kyongsangbuk',
#   'POPULATION': '131097',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2386','Yongju','KOR','Kyongsangbuk','131097');"},
#  {'ID': 2387.0,
#   'NAME': 'Chinhae',
#   'COUNTRYCODE': 'KOR',
#   'DISTRICT': 'Kyongsangnam',
#   'POPULATION': '125997',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2387','Chinhae','KOR','Kyongsangnam','125997');"},
#  {'ID': 2388.0,
#   'NAME': 'Sangju',
#   'COUNTRYCODE': 'KOR',
#   'DISTRICT': 'Kyongsangbuk',
#   'POPULATION': '124116',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2388','Sangju','KOR','Kyongsangbuk','124116');"},
#  {'ID': 2406.0,
#   'NAME': 'Herakleion',
#   'COUNTRYCODE': 'GRC',
#   'DISTRICT': 'Crete',
#   'POPULATION': '116178',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2406','Herakleion','GRC','Crete','116178');"},
#  {'ID': 2440.0,
#   'NAME': 'Monrovia',
#   'COUNTRYCODE': 'LBR',
#   'DISTRICT': 'Montserrado',
#   'POPULATION': '850000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2440','Monrovia','LBR','Montserrado','850000');"},
#  {'ID': 2462.0,
#   'NAME': 'Lilongwe',
#   'COUNTRYCODE': 'MWI',
#   'DISTRICT': 'Lilongwe',
#   'POPULATION': '435964',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2462','Lilongwe','MWI','Lilongwe','435964');"},
#  {'ID': 2505.0,
#   'NAME': 'Taza',
#   'COUNTRYCODE': 'MAR',
#   'DISTRICT': 'Taza-Al Hoceima-Taou',
#   'POPULATION': '92700',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2505','Taza','MAR','Taza-Al Hoceima-Taou','92700');"},
#  {'ID': 2555.0,
#   'NAME': 'Xalapa',
#   'COUNTRYCODE': 'MEX',
#   'DISTRICT': 'Veracruz',
#   'POPULATION': '390058',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2555','Xalapa','MEX','Veracruz','390058');"},
#  {'ID': 2602.0,
#   'NAME': 'Ocosingo',
#   'COUNTRYCODE': 'MEX',
#   'DISTRICT': 'Chiapas',
#   'POPULATION': '171495',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2602','Ocosingo','MEX','Chiapas','171495');"},
#  {'ID': 2609.0,
#   'NAME': 'Nogales',
#   'COUNTRYCODE': 'MEX',
#   'DISTRICT': 'Sonora',
#   'POPULATION': '159103',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2609','Nogales','MEX','Sonora','159103');"},
#  {'ID': 2670.0,
#   'NAME': 'San Pedro Cholula',
#   'COUNTRYCODE': 'MEX',
#   'DISTRICT': 'Puebla',
#   'POPULATION': '99734',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2670','San Pedro Cholula','MEX','Puebla','99734');"},
#  {'ID': 2689.0,
#   'NAME': 'Palikir',
#   'COUNTRYCODE': 'FSM',
#   'DISTRICT': 'Pohnpei',
#   'POPULATION': '8600',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2689','Palikir','FSM','Pohnpei','8600');"},
#  {'ID': 2706.0,
#   'NAME': 'Tete',
#   'COUNTRYCODE': 'MOZ',
#   'DISTRICT': 'Tete',
#   'POPULATION': '101984',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2706','Tete','MOZ','Tete','101984');"},
#  {'ID': 2716.0,
#   'NAME': 'Sittwe (Akyab)',
#   'COUNTRYCODE': 'MMR',
#   'DISTRICT': 'Rakhine',
#   'POPULATION': '137600',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2716','Sittwe (Akyab)','MMR','Rakhine','137600');"},
#  {'ID': 2922.0,
#   'NAME': 'Carolina',
#   'COUNTRYCODE': 'PRI',
#   'DISTRICT': 'Carolina',
#   'POPULATION': '186076',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2922','Carolina','PRI','Carolina','186076');"},
#  {'ID': 2967.0,
#   'NAME': 'Grudziadz',
#   'COUNTRYCODE': 'POL',
#   'DISTRICT': 'Kujawsko-Pomorskie',
#   'POPULATION': '102434',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2967','Grudziadz','POL','Kujawsko-Pomorskie','102434');"},
#  {'ID': 2972.0,
#   'NAME': 'Malabo',
#   'COUNTRYCODE': 'GNQ',
#   'DISTRICT': 'Bioko',
#   'POPULATION': '40000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('2972','Malabo','GNQ','Bioko','40000');"},
#  {'ID': 3073.0,
#   'NAME': 'Essen',
#   'COUNTRYCODE': 'DEU',
#   'DISTRICT': 'Nordrhein-Westfalen',
#   'POPULATION': '599515',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3073','Essen','DEU','Nordrhein-Westfalen','599515');"},
#  {'ID': 3169.0,
#   'NAME': 'Apia',
#   'COUNTRYCODE': 'WSM',
#   'DISTRICT': 'Upolu',
#   'POPULATION': '35900',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3169','Apia','WSM','Upolu','35900');"},
#  {'ID': 3198.0,
#   'NAME': 'Dakar',
#   'COUNTRYCODE': 'SEN',
#   'DISTRICT': 'Cap-Vert',
#   'POPULATION': '785071',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3198','Dakar','SEN','Cap-Vert','785071');"},
#  {'ID': 3253.0,
#   'NAME': 'Hama',
#   'COUNTRYCODE': 'SYR',
#   'DISTRICT': 'Hama',
#   'POPULATION': '343361',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3253','Hama','SYR','Hama','343361');"},
#  {'ID': 3288.0,
#   'NAME': 'Luchou',
#   'COUNTRYCODE': 'TWN',
#   'DISTRICT': 'Taipei',
#   'POPULATION': '160516',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3288','Luchou','TWN','Taipei','160516');"},
#  {'ID': 3309.0,
#   'NAME': 'Tanga',
#   'COUNTRYCODE': 'TZA',
#   'DISTRICT': 'Tanga',
#   'POPULATION': '137400',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3309','Tanga','TZA','Tanga','137400');"},
#  {'ID': 3353.0,
#   'NAME': 'Sousse',
#   'COUNTRYCODE': 'TUN',
#   'DISTRICT': 'Sousse',
#   'POPULATION': '145900',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3353','Sousse','TUN','Sousse','145900');"},
#  {'ID': 3377.0,
#   'NAME': 'Kahramanmaras',
#   'COUNTRYCODE': 'TUR',
#   'DISTRICT': 'Kahramanmaras',
#   'POPULATION': '245772',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3377','Kahramanmaras','TUR','Kahramanmaras','245772');"},
#  {'ID': 3430.0,
#   'NAME': 'Odesa',
#   'COUNTRYCODE': 'UKR',
#   'DISTRICT': 'Odesa',
#   'POPULATION': '1011000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3430','Odesa','UKR','Odesa','1011000');"},
#  {'ID': 3581.0,
#   'NAME': 'St Petersburg',
#   'COUNTRYCODE': 'RUS',
#   'DISTRICT': 'Pietari',
#   'POPULATION': '4694000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3581','St Petersburg','RUS','Pietari','4694000');"},
#  {'ID': 3770.0,
#   'NAME': 'Hanoi',
#   'COUNTRYCODE': 'VNM',
#   'DISTRICT': 'Hanoi',
#   'POPULATION': '1410000',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3770','Hanoi','VNM','Hanoi','1410000');"},
#  {'ID': 3815.0,
#   'NAME': 'El Paso',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Texas',
#   'POPULATION': '563662',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3815','El Paso','USA','Texas','563662');"},
#  {'ID': 3878.0,
#   'NAME': 'Scottsdale',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Arizona',
#   'POPULATION': '202705',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3878','Scottsdale','USA','Arizona','202705');"},
#  {'ID': 3965.0,
#   'NAME': 'Corona',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'California',
#   'POPULATION': '124966',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3965','Corona','USA','California','124966');"},
#  {'ID': 3973.0,
#   'NAME': 'Concord',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'California',
#   'POPULATION': '121780',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3973','Concord','USA','California','121780');"},
#  {'ID': 3977.0,
#   'NAME': 'Cedar Rapids',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Iowa',
#   'POPULATION': '120758',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3977','Cedar Rapids','USA','Iowa','120758');"},
#  {'ID': 3982.0,
#   'NAME': 'Coral Springs',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Florida',
#   'POPULATION': '117549',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('3982','Coral Springs','USA','Florida','117549');"},
#  {'ID': 4054.0,
#   'NAME': 'Fairfield',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'California',
#   'POPULATION': '92256',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('4054','Fairfield','USA','California','92256');"},
#  {'ID': 4058.0,
#   'NAME': 'Boulder',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Colorado',
#   'POPULATION': '91238',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('4058','Boulder','USA','Colorado','91238');"},
#  {'ID': 4061.0,
#   'NAME': 'Fall River',
#   'COUNTRYCODE': 'USA',
#   'DISTRICT': 'Massachusetts',
#   'POPULATION': '90555',
#   'Unnamed: 5': 'insert into city values (',
#   'Unnamed: 6': "insert into city values ('4061','Fall River','USA','Massachusetts','90555');"},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': 'City Table',
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': None,
#   'COUNTRYCODE': None,
#   'DISTRICT': None,
#   'POPULATION': None,
#   'Unnamed: 5': None,
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': 'ID',
#   'COUNTRYCODE': 'NAME',
#   'DISTRICT': 'COUNTRYCODE',
#   'POPULATION': 'DISTRICT',
#   'Unnamed: 5': 'POPULATION',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '6',
#   'COUNTRYCODE': 'Rotterdam',
#   'DISTRICT': 'NLD',
#   'POPULATION': 'Zuid-Holland',
#   'Unnamed: 5': '593321',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '19',
#   'COUNTRYCODE': 'Zaanstad',
#   'DISTRICT': 'NLD',
#   'POPULATION': 'Noord-Holland',
#   'Unnamed: 5': '135621',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '214',
#   'COUNTRYCODE': 'Porto Alegre',
#   'DISTRICT': 'BRA',
#   'POPULATION': 'Rio Grande do Sul',
#   'Unnamed: 5': '1314032',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '397',
#   'COUNTRYCODE': 'Lauro de Freitas',
#   'DISTRICT': 'BRA',
#   'POPULATION': 'Bahia',
#   'Unnamed: 5': '109236',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '547',
#   'COUNTRYCODE': 'Dobric',
#   'DISTRICT': 'BGR',
#   'POPULATION': 'Varna',
#   'Unnamed: 5': '100399',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '552',
#   'COUNTRYCODE': 'Bujumbura',
#   'DISTRICT': 'BDI',
#   'POPULATION': 'Bujumbura',
#   'Unnamed: 5': '300000',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '554',
#   'COUNTRYCODE': 'Santiago de Chile',
#   'DISTRICT': 'CHL',
#   'POPULATION': 'Santiago',
#   'Unnamed: 5': '4703954',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '626',
#   'COUNTRYCODE': 'al-Minya',
#   'DISTRICT': 'EGY',
#   'POPULATION': 'al-Minya',
#   'Unnamed: 5': '201360',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '646',
#   'COUNTRYCODE': 'Santa Ana',
#   'DISTRICT': 'SLV',
#   'POPULATION': 'Santa Ana',
#   'Unnamed: 5': '139389',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '762',
#   'COUNTRYCODE': 'Bahir',
#   'DISTRICT': 'Dar',
#   'POPULATION': 'ETH Amhara',
#   'Unnamed: 5': '96140',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '796',
#   'COUNTRYCODE': 'Baguio',
#   'DISTRICT': 'PHL',
#   'POPULATION': 'CAR',
#   'Unnamed: 5': '252386',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '896',
#   'COUNTRYCODE': 'Malungon',
#   'DISTRICT': 'PHL',
#   'POPULATION': 'Southern Mindanao',
#   'Unnamed: 5': '93232',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '904',
#   'COUNTRYCODE': 'Banjul',
#   'DISTRICT': 'GMB',
#   'POPULATION': 'Banjul',
#   'Unnamed: 5': '42326',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '924',
#   'COUNTRYCODE': 'Villa',
#   'DISTRICT': 'Nueva',
#   'POPULATION': 'GTM',
#   'Unnamed: 5': '101295',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '990',
#   'COUNTRYCODE': 'Waru',
#   'DISTRICT': 'IDN',
#   'POPULATION': 'East Java',
#   'Unnamed: 5': '124300',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1155',
#   'COUNTRYCODE': 'Latur',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Maharashtra',
#   'Unnamed: 5': '197408',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1222',
#   'COUNTRYCODE': 'Tenali',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Andhra Pradesh',
#   'Unnamed: 5': '143726',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1235',
#   'COUNTRYCODE': 'Tirunelveli',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Tamil Nadu',
#   'Unnamed: 5': '135825',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1256',
#   'COUNTRYCODE': 'Alandur',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Tamil Nadu',
#   'Unnamed: 5': '125244',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1279',
#   'COUNTRYCODE': 'Neyveli',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Tamil Nadu',
#   'Unnamed: 5': '118080',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1293',
#   'COUNTRYCODE': 'Pallavaram',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Tamil Nadu',
#   'Unnamed: 5': '111866',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1350',
#   'COUNTRYCODE': 'Dehri',
#   'DISTRICT': 'IND',
#   'POPULATION': 'Bihar',
#   'Unnamed: 5': '94526',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1383',
#   'COUNTRYCODE': 'Tabriz',
#   'DISTRICT': 'IRN',
#   'POPULATION': 'East Azerbaidzan',
#   'Unnamed: 5': '1191043',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1385',
#   'COUNTRYCODE': 'Karaj',
#   'DISTRICT': 'IRN',
#   'POPULATION': 'Teheran',
#   'Unnamed: 5': '940968',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1508',
#   'COUNTRYCODE': 'Bolzano',
#   'DISTRICT': 'ITA',
#   'POPULATION': 'Trentino-Alto Adige',
#   'Unnamed: 5': '97232',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1520',
#   'COUNTRYCODE': 'Cesena',
#   'DISTRICT': 'ITA',
#   'POPULATION': 'Emilia-Romagna',
#   'Unnamed: 5': '89852',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1613',
#   'COUNTRYCODE': 'Neyagawa',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Osaka',
#   'Unnamed: 5': '257315',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1630',
#   'COUNTRYCODE': 'Ageo',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Saitama',
#   'Unnamed: 5': '209442',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1661',
#   'COUNTRYCODE': 'Sayama',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Saitama',
#   'Unnamed: 5': '162472',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1681',
#   'COUNTRYCODE': 'Omuta',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Fukuoka',
#   'Unnamed: 5': '142889',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1739',
#   'COUNTRYCODE': 'Tokuyama',
#   'DISTRICT': 'JPN',
#   'POPULATION': 'Yamaguchi',
#   'Unnamed: 5': '107078',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1793',
#   'COUNTRYCODE': 'Novi Sad',
#   'DISTRICT': 'YUG',
#   'POPULATION': 'Vojvodina',
#   'Unnamed: 5': '179626',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1857',
#   'COUNTRYCODE': 'Kelowna',
#   'DISTRICT': 'CAN',
#   'POPULATION': 'British Colombia',
#   'Unnamed: 5': '89442',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1895',
#   'COUNTRYCODE': 'Harbin',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Heilongjiang',
#   'Unnamed: 5': '4289800',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1900',
#   'COUNTRYCODE': 'Changchun',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Jilin',
#   'Unnamed: 5': '2812000',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1913',
#   'COUNTRYCODE': 'Lanzhou',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Gansu',
#   'Unnamed: 5': '1565800',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '1947',
#   'COUNTRYCODE': 'Changzhou',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Jiangsu',
#   'Unnamed: 5': '530000',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2070',
#   'COUNTRYCODE': 'Dezhou',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Shandong',
#   'Unnamed: 5': '195485',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2081',
#   'COUNTRYCODE': 'Heze',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Shandong',
#   'Unnamed: 5': '189293',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2111',
#   'COUNTRYCODE': 'Chenzhou',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Hunan',
#   'Unnamed: 5': '169400',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2153',
#   'COUNTRYCODE': 'Xianning',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Hubei',
#   'Unnamed: 5': '136811',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2192',
#   'COUNTRYCODE': 'Lhasa',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Tibet',
#   'Unnamed: 5': '120000',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2193',
#   'COUNTRYCODE': 'Lianyuan',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Hunan',
#   'Unnamed: 5': '118858',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2227',
#   'COUNTRYCODE': 'Xingcheng',
#   'DISTRICT': 'CHN',
#   'POPULATION': 'Liaoning',
#   'Unnamed: 5': '102384',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2273',
#   'COUNTRYCODE': 'Villavicencio',
#   'DISTRICT': 'COL',
#   'POPULATION': 'Meta',
#   'Unnamed: 5': '273140',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2384',
#   'COUNTRYCODE': 'Tong-yong',
#   'DISTRICT': 'KOR',
#   'POPULATION': 'Kyongsangnam',
#   'Unnamed: 5': '131717',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2386',
#   'COUNTRYCODE': 'Yongju',
#   'DISTRICT': 'KOR',
#   'POPULATION': 'Kyongsangbuk',
#   'Unnamed: 5': '131097',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2387',
#   'COUNTRYCODE': 'Chinhae',
#   'DISTRICT': 'KOR',
#   'POPULATION': 'Kyongsangnam',
#   'Unnamed: 5': '125997',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2388',
#   'COUNTRYCODE': 'Sangju',
#   'DISTRICT': 'KOR',
#   'POPULATION': 'Kyongsangbuk',
#   'Unnamed: 5': '124116',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2406',
#   'COUNTRYCODE': 'Herakleion',
#   'DISTRICT': 'GRC',
#   'POPULATION': 'Crete',
#   'Unnamed: 5': '116178',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2440',
#   'COUNTRYCODE': 'Monrovia',
#   'DISTRICT': 'LBR',
#   'POPULATION': 'Montserrado',
#   'Unnamed: 5': '850000',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2462',
#   'COUNTRYCODE': 'Lilongwe',
#   'DISTRICT': 'MWI',
#   'POPULATION': 'Lilongwe',
#   'Unnamed: 5': '435964',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2505',
#   'COUNTRYCODE': 'Taza',
#   'DISTRICT': 'MAR',
#   'POPULATION': 'Taza-Al Hoceima-Taou',
#   'Unnamed: 5': '92700',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2555',
#   'COUNTRYCODE': 'Xalapa',
#   'DISTRICT': 'MEX',
#   'POPULATION': 'Veracruz',
#   'Unnamed: 5': '390058',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2602',
#   'COUNTRYCODE': 'Ocosingo',
#   'DISTRICT': 'MEX',
#   'POPULATION': 'Chiapas',
#   'Unnamed: 5': '171495',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2609',
#   'COUNTRYCODE': 'Nogales',
#   'DISTRICT': 'MEX',
#   'POPULATION': 'Sonora',
#   'Unnamed: 5': '159103',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2670',
#   'COUNTRYCODE': 'San Pedro Cholula',
#   'DISTRICT': 'MEX',
#   'POPULATION': 'Puebla',
#   'Unnamed: 5': '99734',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2689',
#   'COUNTRYCODE': 'Palikir',
#   'DISTRICT': 'FSM',
#   'POPULATION': 'Pohnpei',
#   'Unnamed: 5': '8600',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2706',
#   'COUNTRYCODE': 'Tete',
#   'DISTRICT': 'MOZ',
#   'POPULATION': 'Tete',
#   'Unnamed: 5': '101984',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2716',
#   'COUNTRYCODE': 'Sittwe (Akyab)',
#   'DISTRICT': 'MMR',
#   'POPULATION': 'Rakhine',
#   'Unnamed: 5': '137600',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2922',
#   'COUNTRYCODE': 'Carolina',
#   'DISTRICT': 'PRI',
#   'POPULATION': 'Carolina',
#   'Unnamed: 5': '186076',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2967',
#   'COUNTRYCODE': 'Grudziadz',
#   'DISTRICT': 'POL',
#   'POPULATION': 'Kujawsko-Pomorskie',
#   'Unnamed: 5': '102434',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '2972',
#   'COUNTRYCODE': 'Malabo',
#   'DISTRICT': 'GNQ',
#   'POPULATION': 'Bioko',
#   'Unnamed: 5': '40000',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3073',
#   'COUNTRYCODE': 'Essen',
#   'DISTRICT': 'DEU',
#   'POPULATION': 'Nordrhein-Westfalen',
#   'Unnamed: 5': '599515',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3169',
#   'COUNTRYCODE': 'Apia',
#   'DISTRICT': 'WSM',
#   'POPULATION': 'Upolu',
#   'Unnamed: 5': '35900',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3198',
#   'COUNTRYCODE': 'Dakar',
#   'DISTRICT': 'SEN',
#   'POPULATION': 'Cap-Vert',
#   'Unnamed: 5': '785071',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3253',
#   'COUNTRYCODE': 'Hama',
#   'DISTRICT': 'SYR',
#   'POPULATION': 'Hama',
#   'Unnamed: 5': '343361',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3288',
#   'COUNTRYCODE': 'Luchou',
#   'DISTRICT': 'TWN',
#   'POPULATION': 'Taipei',
#   'Unnamed: 5': '160516',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3309',
#   'COUNTRYCODE': 'Tanga',
#   'DISTRICT': 'TZA',
#   'POPULATION': 'Tanga',
#   'Unnamed: 5': '137400',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3353',
#   'COUNTRYCODE': 'Sousse',
#   'DISTRICT': 'TUN',
#   'POPULATION': 'Sousse',
#   'Unnamed: 5': '145900',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3377',
#   'COUNTRYCODE': 'Kahramanmaras',
#   'DISTRICT': 'TUR',
#   'POPULATION': 'Kahramanmaras',
#   'Unnamed: 5': '245772',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3430',
#   'COUNTRYCODE': 'Odesa',
#   'DISTRICT': 'UKR',
#   'POPULATION': 'Odesa',
#   'Unnamed: 5': '1011000',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3581',
#   'COUNTRYCODE': 'St Petersburg',
#   'DISTRICT': 'RUS',
#   'POPULATION': 'Pietari',
#   'Unnamed: 5': '4694000',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3770',
#   'COUNTRYCODE': 'Hanoi',
#   'DISTRICT': 'VNM',
#   'POPULATION': 'Hanoi',
#   'Unnamed: 5': '1410000',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3815',
#   'COUNTRYCODE': 'El Paso',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Texas',
#   'Unnamed: 5': '563662',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3878',
#   'COUNTRYCODE': 'Scottsdale',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Arizona',
#   'Unnamed: 5': '202705',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3965',
#   'COUNTRYCODE': 'Corona',
#   'DISTRICT': 'USA',
#   'POPULATION': 'California',
#   'Unnamed: 5': '124966',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3973',
#   'COUNTRYCODE': 'Concord',
#   'DISTRICT': 'USA',
#   'POPULATION': 'California',
#   'Unnamed: 5': '121780',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3977',
#   'COUNTRYCODE': 'Cedar Rapids',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Iowa',
#   'Unnamed: 5': '120758',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '3982',
#   'COUNTRYCODE': 'Coral Springs',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Florida',
#   'Unnamed: 5': '117549',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '4054',
#   'COUNTRYCODE': 'Fairfield',
#   'DISTRICT': 'USA',
#   'POPULATION': 'California',
#   'Unnamed: 5': '92256',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '4058',
#   'COUNTRYCODE': 'Boulder',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Colorado',
#   'Unnamed: 5': '91238',
#   'Unnamed: 6': None},
#  {'ID': None,
#   'NAME': '4061',
#   'COUNTRYCODE': 'Fall River',
#   'DISTRICT': 'USA',
#   'POPULATION': 'Massachusetts',
#   'Unnamed: 5': '90555',
#   'Unnamed: 6': None}]

# %%
multiplerecords = list(json.loads(df.T.to_json()).values())

# %%
mycol2.insert_many(multiplerecords)
